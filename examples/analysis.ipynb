# %%
import os
path_input = "/data/output_test/rocs/results_01_individual.h5"
path_input
# Out:
# '/data/output_test/rocs/results_01_individual.h5'

# %%
import pandas as pd

# %%
df = pd.read_hdf(path_input)
# df.index = df.index.set_names(['path', 'model', 'run id'])

# %%
df
# Out:
#                                                       fit time  roc time  \
# path                                model     run id
#  data sampledata machinetype1 id00  MFCCMix M 0       2.097073  1.365679
#                                               1       0.828584  1.486489
#                                               2       0.839522  1.487346
#                                     MFCCMix S 0       0.867808  1.233778
#                                               1       0.894101  1.243001
#                                               2       0.743127  1.246256
#
#                                                       roc value
# path                                model     run id
#  data sampledata machinetype1 id00  MFCCMix M 0            0.40
#                                               1            0.40
#                                               2            0.40
#                                     MFCCMix S 0            0.64
# ...

# %%
df_mean = df.groupby(level=[0,1]).mean()
df_mean
# Out:
#                                                fit time  roc time  roc value
# path                                model
#  data sampledata machinetype1 id00  MFCCMix M  1.255060  1.446505       0.40
#                                     MFCCMix S  0.835012  1.241012       0.64

# %%
df_std = df.groupby(level=[0,1]).std()
df_std
# Out:
#                                                fit time  roc time  roc value
# path                                model
#  data sampledata machinetype1 id00  MFCCMix M  0.729226  0.069998        0.0
#                                     MFCCMix S  0.080654  0.006473        0.0
