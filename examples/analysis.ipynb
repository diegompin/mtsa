# %%
import os
path_input = "/data/output_test/rocs/results_01_individual.h5"
path_input
# Out:
# '/data/output_test/rocs/results_01_individual.h5'

# %%
import pandas as pd

# %%
df = pd.read_hdf(path_input)
# df.index = df.index.set_names(['path', 'model', 'run id'])

# %%
df_mean = df.groupby(level=["path","model"], group_keys=False).mean()
df_mean['run id'] = 'mean'
df_mean.set_index('run id', append=True, inplace=True)

df_std = df.groupby(level=["path","model"], group_keys=False).std()
df_std['run id'] = 'std'
df_std.set_index('run id', append=True, inplace=True)


df_final = pd.concat([
    df, 
    df_mean,
    df_std
    ]
    )
df_final
# Out:
#                                                       fit time  roc time  \
# path                                model     run id
#  data sampledata machinetype1 id00  Baseline  0       6.116847  8.848354
#                                               1       3.816732  8.693612
#                                               2       4.012215  8.343199
#                                     MFCCMix M 0       0.688115  1.082547
#                                               1       0.611746  1.111562
#                                               2       0.621378  1.106166
#                                     Baseline  mean    4.648598  8.628388
#                                     MFCCMix M mean    0.640413  1.100092
#                                     Baseline  std     1.275292  0.258817
#                                     MFCCMix M std     0.041591  0.015432
#
#                                                       roc value
# path                                model     run id
#  data sampledata machinetype1 id00  Baseline  0            0.48
#                                               1            0.48
#                                               2            0.48
#                                     MFCCMix M 0            0.36
#                                               1            0.36
#                                               2            0.36
#                                     Baseline  mean         0.48
#                                     MFCCMix M mean         0.36
#                                     Baseline  std          0.00
#                                     MFCCMix M std          0.00
